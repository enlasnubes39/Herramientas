# %%
# 1. INSTALACIÓN DE HERRAMIENTAS (Solo se hace una vez al abrir el cuaderno)
# !sudo curl -L https://github.com/yt-dlp/yt-dlp/releases/latest/download/yt-dlp -o /usr/local/bin/yt-dlp
# !sudo chmod a+rx /usr/local/bin/yt-dlp
print("✅ Herramientas listas para usar")

# %%
#@title 🚀 Panel de Control de Descarga
#@markdown Introduce los datos y presiona el botón de 'Play' a la izquierda.

url_del_video = "" #@param {type:"string"}
nombre_del_archivo = "Clase_Nueva.mp4" #@param {type:"string"}
calidad_maxima = "720" #@param ["360", "480", "720", "1080"]

import os
from google.colab import files

if url_del_video == "":
    print("❌ Por favor, pega una URL válida.")
else:
    print(f"🎬 Preparando descarga de: {nombre_del_archivo}")

    # Ejecutamos la descarga usando las variables del formulario
    # !yt-dlp -f "bestvideo[height<={calidad_maxima}]+bestaudio/best" "{url_del_video}" \
        --concurrent-fragments 5 \
        -o "{nombre_del_archivo}"

    if os.path.exists(nombre_del_archivo):
        print(f"✅ ¡Éxito! El archivo se ha generado correctamente.")
        files.download(nombre_del_archivo)
    else:
        print("❌ Error: Algo ha fallado. Revisa el enlace.")
